# %%
import pandas as pd

# %%
b=pd.read_csv("P  L March 2021.csv") 
b.head(1) #2021 product info
# Out:
#    index   Product_SKU Product_Style_ID Product_Catalog Product_Category  \
# 0      0  Os206_3141_S       Os206_3141         Moments            Kurta
#
#   Product_Weight Transfer_Price_Level_1 Transfer_Price_Level_2 Old_MRP  \
# 0            0.3                    538                 435.78    2178
#
#   Final_Old_MRP Ajio_MRP Amazon_MRP Amazon_FBA_MRP Flipkart_MRP Limeroad_MRP  \
# 0          2295     2295       2295           2295         2295         2295
#
#   Myntra_MRP Paytm_MRP Snapdeal_MRP
# 0       2295      2295         2295

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   1330 non-null   int64
#  1   Product_SKU             1330 non-null   object
#  2   Product_Style_ID        1330 non-null   object
#  3   Product_Catalog         1330 non-null   object
#  4   Product_Category        1330 non-null   object
#  5   Product_Weight          1330 non-null   object
#  6   Transfer_Price_Level_1  1330 non-null   object
#  7   Transfer_Price_Level_2  1330 non-null   object
#  8   Old_MRP                 1330 non-null   object
#  9   Final_Old_MRP           1330 non-null   object
#  10  Ajio_MRP                1330 non-null   object
#  11  Amazon_MRP              1330 non-null   object
#  12  Amazon_FBA_MRP          1330 non-null   object
#  13  Flipkart_MRP            1330 non-null   object
#  14  Limeroad_MRP            1330 non-null   object
#  15  Myntra_MRP              1330 non-null   object
#  16  Paytm_MRP               1330 non-null   object
#  17  Snapdeal_MRP            1330 non-null   object
# dtypes: int64(1), object(17)
# memory usage: 187.2+ KB

# %%
b.nunique()
# Out:
# index                     1330
# Product_SKU               1330
# Product_Style_ID           254
# Product_Catalog              9
# Product_Category             5
# Product_Weight               4
# Transfer_Price_Level_1      93
# Transfer_Price_Level_2      93
# Old_MRP                     67
# Final_Old_MRP               53
# Ajio_MRP                    52
# Amazon_MRP                  53
# Amazon_FBA_MRP              53
# Flipkart_MRP                52
# Limeroad_MRP                52
# Myntra_MRP                  51
# Paytm_MRP                   52
# Snapdeal_MRP                52
# dtype: int64

# %%
# Find rows in Transfer_Price with non-numeric values
invalid_transfer_price = b[~b['Transfer_Price_Level_2'].str.replace(',', '').str.isnumeric()]


# Find rows in Final_Old_MRP with non-numeric values
count_nill = (b['Final_Old_MRP'].str.strip().str.lower() == 'nill').sum()
print("Number of rows with 'Nill' in Final_Old_MRP:", count_nill)
invalid_final_old_mrp = b[~b['Final_Old_MRP'].str.replace(',', '').str.isnumeric()]
print("Rows with invalid Final_Old_MRP:")
print(invalid_final_old_mrp)
# Out:
# Number of rows with 'Nill' in Final_Old_MRP: 37
# Rows with invalid Final_Old_MRP:
#       index            Product_SKU    Product_Style_ID Product_Catalog  \
# 1104   1104                Os312_S               Os312             Mix
# 1105   1105                Os312_M               Os312             Mix
# 1106   1106                Os312_L               Os312             Mix
# 1107   1107               Os312_XL               Os312             Mix
# 1108   1108              Os312_2XL               Os312             Mix
# 1109   1109              Os312_3XL               Os312             Mix
# 1110   1110              Os312KR_S             Os312KR             Mix
# 1111   1111              Os312KR_M             Os312KR             Mix
# 1112   1112              Os312KR_L             Os312KR             Mix
# 1113   1113             Os312KR_XL             Os312KR             Mix
# 1114   1114            Os312KR_2XL             Os312KR             Mix
# 1115   1115            Os312KR_3XL             Os312KR             Mix
# 1140   1140              Os279KR_S             Os279KR             Mix
# 1141   1141              Os279KR_M             Os279KR             Mix
# 1142   1142              Os279KR_L             Os279KR             Mix
# 1143   1143             Os279KR_XL             Os279KR             Mix
# 1144   1144            Os279KR_2XL             Os279KR             Mix
# 1145   1145            Os279KR_3XL             Os279KR             Mix
# 1176   1176                Os311_S               Os311             Mix
# 1177   1177                Os311_M               Os311             Mix
# 1178   1178                Os311_L               Os311             Mix
# 1179   1179               Os311_XL               Os311             Mix
# 1180   1180              Os311_2XL               Os311             Mix
# 1181   1181              Os311_3XL               Os311             Mix
# 1182   1182              Os311KR_S             Os311KR             Mix
# 1183   1183              Os311KR_M             Os311KR             Mix
# 1184   1184              Os311KR_L             Os311KR             Mix
# 1185   1185             Os311KR_XL             Os311KR             Mix
# 1186   1186            Os311KR_2XL             Os311KR             Mix
# 1187   1187            Os311KR_3XL             Os311KR             Mix
# 1230   1230               Os1041_S              Os1041             Mix
# 1231   1231               Os1041_M              Os1041             Mix
# 1232   1232               Os1041_L              Os1041             Mix
# 1233   1233              Os1041_XL              Os1041             Mix
# 1234   1234             Os1041_2XL              Os1041             Mix
# 1235   1235             Os1041_3XL              Os1041             Mix
# 1261   1261                OS-1029             OS-1029            Nill
# 1301   1301  BIG CHECKS - 1 BAG_XL  BIG CHECKS - 1 BAG            Nill
# 1305   1305       MIRROR - 1 BAG_L      MIRROR - 1 BAG            Nill
#
#      Product_Category Product_Weight Transfer_Price_Level_1  \
# 1104        Kurta Set            0.4                    635
# 1105        Kurta Set            0.4                    635
# 1106        Kurta Set            0.4                    635
# 1107        Kurta Set            0.4                    635
# 1108        Kurta Set            0.4                    635
# 1109        Kurta Set            0.4                    635
# 1110            Kurta            0.3                   2095
# 1111            Kurta            0.3                   2095
# 1112            Kurta            0.3                   2095
# 1113            Kurta            0.3                   2095
# 1114            Kurta            0.3                   2095
# 1115            Kurta            0.3                   2095
# 1140            Kurta            0.3                    400
# 1141            Kurta            0.3                    400
# 1142            Kurta            0.3                    400
# 1143            Kurta            0.3                    400
# 1144            Kurta            0.3                    400
# 1145            Kurta            0.3                    400
# 1176        Kurta Set            0.4                    599
# 1177        Kurta Set            0.4                    599
# 1178        Kurta Set            0.4                    599
# 1179        Kurta Set            0.4                    599
# 1180        Kurta Set            0.4                    599
# 1181        Kurta Set            0.4                    599
# 1182            Kurta            0.3                    485
# 1183            Kurta            0.3                    485
# 1184            Kurta            0.3                    485
# 1185            Kurta            0.3                    485
# 1186            Kurta            0.3                    485
# 1187            Kurta            0.3                    485
# 1230        Kurta Set            0.4                #VALUE!
# 1231        Kurta Set            0.4                #VALUE!
# 1232        Kurta Set            0.4                #VALUE!
# 1233        Kurta Set            0.4                #VALUE!
# 1234        Kurta Set            0.4                #VALUE!
# 1235        Kurta Set            0.4                #VALUE!
# 1261             Nill           Nill                   2095
# 1301             Nill           Nill                  630.5
# 1305             Nill           Nill                 733.95
#
#      Transfer_Price_Level_2 Old_MRP Final_Old_MRP Ajio_MRP Amazon_MRP  \
# 1104                 514.35    Nill          Nill     Nill       Nill
# 1105                 514.35    Nill          Nill     Nill       Nill
# 1106                 514.35    Nill          Nill     Nill       Nill
# 1107                 514.35    Nill          Nill     Nill       Nill
# 1108                 514.35    Nill          Nill     Nill       Nill
# 1109                 514.35    Nill          Nill     Nill       Nill
# 1110                1696.95    Nill          Nill     Nill       Nill
# 1111                1696.95    Nill          Nill     Nill       Nill
# 1112                1696.95    Nill          Nill     Nill       Nill
# 1113                1696.95    Nill          Nill     Nill       Nill
# 1114                1696.95    Nill          Nill     Nill       Nill
# 1115                1696.95    Nill          Nill     Nill       Nill
# 1140                    324    Nill          Nill     Nill       Nill
# 1141                    324    Nill          Nill     Nill       Nill
# 1142                    324    Nill          Nill     Nill       Nill
# 1143                    324    Nill          Nill     Nill       Nill
# 1144                    324    Nill          Nill     Nill       Nill
# 1145                    324    Nill          Nill     Nill       Nill
# 1176                 485.19    Nill          Nill     Nill       Nill
# 1177                 485.19    Nill          Nill     Nill       Nill
# 1178                 485.19    Nill          Nill     Nill       Nill
# 1179                 485.19    Nill          Nill     Nill       Nill
# 1180                 485.19    Nill          Nill     Nill       Nill
# 1181                 485.19    Nill          Nill     Nill       Nill
# 1182                 392.85    Nill          Nill     Nill       Nill
# 1183                 392.85    Nill          Nill     Nill       Nill
# 1184                 392.85    Nill          Nill     Nill       Nill
# 1185                 392.85    Nill          Nill     Nill       Nill
# 1186                 392.85    Nill          Nill     Nill       Nill
# 1187                 392.85    Nill          Nill     Nill       Nill
# 1230                #VALUE!    Nill          Nill     Nill       Nill
# 1231                #VALUE!    Nill          Nill     Nill       Nill
# 1232                #VALUE!    Nill          Nill     Nill       Nill
# 1233                #VALUE!    Nill          Nill     Nill       Nill
# 1234                #VALUE!    Nill          Nill     Nill       Nill
# 1235                #VALUE!    Nill          Nill     Nill       Nill
# 1261                1696.95    Nill          Nill     Nill       Nill
# 1301                  510.7   630.5         630.5    630.5      630.5
# 1305                  594.5  733.95        733.95   733.95     733.95
#
#      Amazon_FBA_MRP Flipkart_MRP Limeroad_MRP Myntra_MRP Paytm_MRP  \
# 1104           Nill         Nill         Nill       Nill      Nill
# 1105           Nill         Nill         Nill       Nill      Nill
# 1106           Nill         Nill         Nill       Nill      Nill
# 1107           Nill         Nill         Nill       Nill      Nill
# 1108           Nill         Nill         Nill       Nill      Nill
# 1109           Nill         Nill         Nill       Nill      Nill
# 1110           Nill         Nill         Nill       Nill      Nill
# 1111           Nill         Nill         Nill       Nill      Nill
# 1112           Nill         Nill         Nill       Nill      Nill
# 1113           Nill         Nill         Nill       Nill      Nill
# 1114           Nill         Nill         Nill       Nill      Nill
# 1115           Nill         Nill         Nill       Nill      Nill
# 1140           Nill         Nill         Nill       Nill      Nill
# 1141           Nill         Nill         Nill       Nill      Nill
# 1142           Nill         Nill         Nill       Nill      Nill
# 1143           Nill         Nill         Nill       Nill      Nill
# 1144           Nill         Nill         Nill       Nill      Nill
# 1145           Nill         Nill         Nill       Nill      Nill
# 1176           Nill         Nill         Nill       Nill      Nill
# 1177           Nill         Nill         Nill       Nill      Nill
# 1178           Nill         Nill         Nill       Nill      Nill
# 1179           Nill         Nill         Nill       Nill      Nill
# 1180           Nill         Nill         Nill       Nill      Nill
# 1181           Nill         Nill         Nill       Nill      Nill
# 1182           Nill         Nill         Nill       Nill      Nill
# 1183           Nill         Nill         Nill       Nill      Nill
# 1184           Nill         Nill         Nill       Nill      Nill
# 1185           Nill         Nill         Nill       Nill      Nill
# 1186           Nill         Nill         Nill       Nill      Nill
# 1187           Nill         Nill         Nill       Nill      Nill
# 1230           Nill         Nill         Nill       2895      Nill
# 1231           Nill         Nill         Nill       2895      Nill
# 1232           Nill         Nill         Nill       2895      Nill
# 1233           Nill         Nill         Nill       2895      Nill
# 1234           Nill         Nill         Nill       2895      Nill
# 1235           Nill         Nill         Nill       2895      Nill
# 1261           Nill         Nill         Nill       Nill      Nill
# 1301          630.5        630.5        630.5      630.5     630.5
# 1305         733.95       733.95       733.95     733.95    733.95
#
#      Snapdeal_MRP
# 1104         Nill
# 1105         Nill
# 1106         Nill
# 1107         Nill
# 1108         Nill
# 1109         Nill
# 1110         Nill
# 1111         Nill
# 1112         Nill
# 1113         Nill
# 1114         Nill
# 1115         Nill
# 1140         Nill
# 1141         Nill
# 1142         Nill
# 1143         Nill
# 1144         Nill
# 1145         Nill
# 1176         Nill
# 1177         Nill
# 1178         Nill
# 1179         Nill
# 1180         Nill
# 1181         Nill
# 1182         Nill
# 1183         Nill
# 1184         Nill
# 1185         Nill
# 1186         Nill
# 1187         Nill
# 1230         Nill
# 1231         Nill
# 1232         Nill
# 1233         Nill
# 1234         Nill
# 1235         Nill
# 1261         Nill
# 1301        630.5
# 1305       733.95

# %%
# Remove rows where Final_Old_MRP == 'Nill'
b = b[b['Final_Old_MRP'].str.strip().str.lower() != 'nill']


# Check results
print(b.shape)
print(b.head())
# Out:
# (1293, 18)
#    index     Product_SKU Product_Style_ID Product_Catalog Product_Category  \
# 0      0    Os206_3141_S       Os206_3141         Moments            Kurta
# 1      1    Os206_3141_M       Os206_3141         Moments            Kurta
# 2      2    Os206_3141_L       Os206_3141         Moments            Kurta
# 3      3   Os206_3141_XL       Os206_3141         Moments            Kurta
# 4      4  Os206_3141_2XL       Os206_3141         Moments            Kurta
#
#   Product_Weight Transfer_Price_Level_1 Transfer_Price_Level_2 Old_MRP  \
# 0            0.3                    538                 435.78    2178
# 1            0.3                    538                 435.78    2178
# 2            0.3                    538                 435.78    2178
# 3            0.3                    538                 435.78    2178
# 4            0.3                    538                 435.78    2178
#
#   Final_Old_MRP Ajio_MRP Amazon_MRP Amazon_FBA_MRP Flipkart_MRP Limeroad_MRP  \
# 0          2295     2295       2295           2295         2295         2295
# 1          2295     2295       2295           2295         2295         2295
# 2          2295     2295       2295           2295         2295         2295
# 3          2295     2295       2295           2295         2295         2295
# 4          2295     2295       2295           2295         2295         2295
#
#   Myntra_MRP Paytm_MRP Snapdeal_MRP
# 0       2295      2295         2295
# 1       2295      2295         2295
# 2       2295      2295         2295
# 3       2295      2295         2295
# 4       2295      2295         2295

# %%
unique_weights = b['Product_Weight'].unique()
print(unique_weights)
count_nill = (b['Product_Weight'].str.strip().str.lower() == 'nill').sum()
print("Number of rows with 'Nill' in Product_Weight:", count_nill)

b = b.replace('Nill', 0)
# Out:
# ['0.3' '0.4' '0.2' 'Nill']
# Number of rows with 'Nill' in Product_Weight: 72

# %%
# Assuming your original DataFrame is named df
columns_to_remove = [
    'index','Old_MRP','Transfer_Price_Level_1', 'Ajio_MRP', 'Amazon_MRP', 'Amazon_FBA_MRP', 
    'Flipkart_MRP', 'Limeroad_MRP', 'Myntra_MRP', 'Paytm_MRP', 'Snapdeal_MRP'
]
c=b.copy()
# Assign df to b first, then drop columns
c = c.drop(columns=columns_to_remove)

# Check the result
print(c.head())
# Out:
#       Product_SKU Product_Style_ID Product_Catalog Product_Category  \
# 0    Os206_3141_S       Os206_3141         Moments            Kurta
# 1    Os206_3141_M       Os206_3141         Moments            Kurta
# 2    Os206_3141_L       Os206_3141         Moments            Kurta
# 3   Os206_3141_XL       Os206_3141         Moments            Kurta
# 4  Os206_3141_2XL       Os206_3141         Moments            Kurta
#
#   Product_Weight Transfer_Price_Level_2 Final_Old_MRP
# 0            0.3                 435.78          2295
# 1            0.3                 435.78          2295
# 2            0.3                 435.78          2295
# 3            0.3                 435.78          2295
# 4            0.3                 435.78          2295

# %%
c = c.rename(columns={
    'Product_SKU': 'sku',
    'Product_Style_ID': 'style',
    'Product_Catalog': 'catalog',
    'Product_Category': 'category',
    'Product_Weight': 'weight',
    'Transfer_Price_Level_2': 'cost_price',
    'Final_Old_MRP': 'mrp'
})

# Check result
print(c.head())
# Out:
#               sku       style  catalog category weight cost_price   mrp
# 0    Os206_3141_S  Os206_3141  Moments    Kurta    0.3     435.78  2295
# 1    Os206_3141_M  Os206_3141  Moments    Kurta    0.3     435.78  2295
# 2    Os206_3141_L  Os206_3141  Moments    Kurta    0.3     435.78  2295
# 3   Os206_3141_XL  Os206_3141  Moments    Kurta    0.3     435.78  2295
# 4  Os206_3141_2XL  Os206_3141  Moments    Kurta    0.3     435.78  2295

# %%
# Convert to float
c['cost_price'] = c['cost_price'].astype(float)
c['mrp'] = c['mrp'].astype(float)

# Convert to float with 2 decimals
c['weight'] = c['weight'].astype(float).round(2)

c = c.astype({
    'sku': 'string',
    'catalog': 'string',
    'category': 'string',
    'style': 'string'
})

# Check the result
print(c.dtypes)
# Out:
# sku           string[python]
# style         string[python]
# catalog       string[python]
# category      string[python]
# weight               float64
# cost_price           float64
# mrp                  float64
# dtype: object

# %%
c.to_csv('new_2021_product_info.csv', index=False)
