# %%
import pandas as pd

# Read all 4 datasets
print("Reading datasets...\n")

# 1. National sales data
national_sales = pd.read_csv("new_amazon_national_sales.csv")
print(f"1. National Sales Data:")
print(f"   Rows: {len(national_sales)}")
print(f"   Columns: {list(national_sales.columns)}")
print(f"   Sample:\n{national_sales.head(2)}\n")

# 2. International sales data
international_sales = pd.read_csv("new_international_sales_report.csv")
print(f"2. International Sales Data:")
print(f"   Rows: {len(international_sales)}")
print(f"   Columns: {list(international_sales.columns)}")
print(f"   Sample:\n{international_sales.head(2)}\n")

# 3. Product info 2022
product_2022 = pd.read_csv("new_2022_product_info.csv")
print(f"3. Product Info 2022:")
print(f"   Rows: {len(product_2022)}")
print(f"   Columns: {list(product_2022.columns)}")
print(f"   Sample:\n{product_2022.head(2)}\n")

# 4. Product info 2021
product_2021 = pd.read_csv("new_2021_product_info.csv")
print(f"4. Product Info 2021:")
print(f"   Rows: {len(product_2021)}")
print(f"   Columns: {list(product_2021.columns)}")
print(f"   Sample:\n{product_2021.head(2)}\n")

print("✅ All datasets loaded successfully!")
# Out:
# Reading datasets...
#
# 1. National Sales Data:
#    Rows: 118806
#    Columns: ['Order_ID', 'date', 'Order_Status', 'Fulfillment_Type', 'shipping_level', 'style', 'sku', 'category', 'size', 'Amazon_Standard_ID', 'quantity', 'sale', 'city', 'state', 'postal_code', 'b2b', 'Promotion_ID_Count', 'avg. value']
#    Sample:
#               Order_ID        date                  Order_Status  \
# 0  171-5348080-7305151  2022-05-15  Shipped - Delivered to Buyer
# 1  403-5947400-5519542  2022-06-01  Shipped - Delivered to Buyer
#
#   Fulfillment_Type shipping_level   style              sku category size  \
# 0         Merchant       Standard  SET355  SET355-KR-PP-XS      Set   XS
# 1         Merchant       Standard  SET144  SET144-KR-NP-XS      Set   XS
#
#   Amazon_Standard_ID  quantity  sale city          state  postal_code    b2b  \
# 0         B09RKDQHR3         1  1229  NaN  UTTAR PRADESH       226002  False
# 1         B0822RTHVK         1   774  NaN  UTTAR PRADESH       226002  False
# ...
